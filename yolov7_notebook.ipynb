# %% [markdown]
# # Hello and Welcome! Ready to know YOLOv7
#
# This is a project of Artificial Intelligences in Thomas More Geel.

# %% [markdown]
# ## First! if you are working in Colab
#
# We need to conect with the google drive in order to save all the files rom yolov7 but also to use the custom dataset.
# This is really simple, you only need to create the folder or folders in you drive and then just using the next code:

# %%
#IF YOU ARE USING THE DESKTOP TO RUN THE YOLO, THEN AVOID THIS BLOCK... TOO LATE?
from google.colab import drive
drive.mount("/content/gdrive") #here we conect to the drive, it will ask for permissions
# %cd /content/gdrive/MyDrive/Colab_assets/ #this is the path I have for the folders I created

#that's it!
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Colab_assets/yolov7

# %% [markdown]
# ## Now let's get the YOLOv7 files
#
# In order to use YOLOv7 we need to get it, obviously!
# This is done by using he github repository of YOLOv7

# %%
# Download YOLOv7 repository and install requirements
# !git clone https://github.com/WongKinYiu/yolov7
# Out:
# c:\Users\david\Documents\Thomas More Sept-2022\Artificial Intelligence Project\Project\yolov7
# fatal: destination path 'yolov7' already exists and is not an empty directory.

# %%
# %cd ./yolov7/ #Now let's move to the YOLOv7 directory
# Out:
# [WinError 2] The system cannot find the file specified: './yolov7/'
# c:\Users\david\Documents\Thomas More Sept-2022\Artificial Intelligence Project\Project\yolov7

# %% [markdown]
# ## Installing the requierements
#
# After getting the YOLOv7 files, and before to install the requierements, it is necessary to make some changes..
#
# - In the requierements.txt ---> Delete the 2 lines with torch and torchvision
# - Create the  requirements_gpu.txt ---> Add this lines:
#
# ```t
# -i https://download.pytorch.org/whl/cu113
# torch==1.12.1+cu113
# torchvision==0.13.1+cu113
# ```
#
#
#
#
# Now you can run the next block:

# %%
# !pip install -r requirements.txt
# !pip install -r requirements_gpu.txt

# %% [markdown]
# ## One last thing we need to download is the weights
#
# It just need to be runned once..

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt
#this aybe don't works in Windows... go to the link and download it yourself then. Easy as that
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Now some changes for our custome data
#
#
# ### Creating a custom_data.yaml
#
# - Go to ./data/ ---> Create a copy of coco.yaml and called: <b>custom_data.yaml </b>
# - Then comment or delete all the code and paste this:
#
# ```t
#
# train: /data/train  #
# val: /data/val  #
#
# # number of classes
# nc: 1 #Only for flowers now
#
# # class names
# names: [ 'flower' ]
#
# ```
#
# ### Creating a yolov7-custome.yaml
#
# - Go to ./cfg/training/ ---> Create a copy of yolov7.yaml and called: <b>yolov7-custome.yaml </b>
# - Then just change the <b>nc</b> variable for 1:
#
# ```t
# #parameters
# nc: 1 #Because now we are using just one class
# ...
#
# ```

# %% [markdown]
# ## Now it is time for your own data
#
# Put all the data in the directory ./data/
#
# But remember 2 folders are needed at least, <b>train</b> and <b>val</b>.
#
# And inside every folder (train and val) should be also 2 other folders, one with the <b>images</b> and other with the <b>labels</b>
#
# If you only have the images then you can easelly label the data with https://www.makesense.ai/
#
# Enjoy!

# %% [markdown]
# ## Ready to train!
# There is some important information you need to know...
#
# And know that you know it, run the code:

# %%
# run this cell to begin training
# !python train.py --batch-size 12 --epochs 30 --img 640 640 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7_custom.yaml --name yolov7-custom --weights yolov7.pt --device 0
# Out:
# YOLOR 🚀 v0.1-115-g072f76c torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=12, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7_custom.yaml', data='data/custom_data.yaml', device='0', entity=None, epochs=30, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.custom.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7-custom', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7-custom6', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=12, upload_dataset=False, v5_metric=False, weights='yolov7.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# ## Once the training is finished
#
# You have to follow the next steps in order to use the new weights:
#
# - go to .runs\train  and select the folder you created with the training, inside go to weights and inside select best.pt
# - make a copy of best.pt and rename it to yolov7_custom.pt
# - move the yolov7_custom.pt to the main folder (./)

# %% [markdown]
# # Ok, it is time to test how good the model is!

# %%
# %ls #just checking the directory
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is B0E9-C685
#
#  Directory of c:\Users\david\Documents\Thomas More Sept-2022\Artificial Intelligence Project\Project\yolov7
#
# 28/11/2022  22:34    <DIR>          .
# 28/11/2022  21:40    <DIR>          ..
# 28/11/2022  21:41             4,325 .gitignore
# 28/11/2022  21:41    <DIR>          cfg
# 28/11/2022  22:10    <DIR>          data
# 28/11/2022  21:41    <DIR>          deploy
# 28/11/2022  21:41             9,523 detect.py
# 28/11/2022  21:41             9,367 export.py
# 28/11/2022  21:41    <DIR>          figure
# 28/11/2022  22:29           579,661 flower1.jpg
# 28/11/2022  22:30           543,367 flower2.jpg
# 28/11/2022  22:30           567,200 flower3.jpg
# 28/11/2022  22:30           679,536 flower4.jpg
# 28/11/2022  21:41             3,680 hubconf.py
# 28/11/2022  21:41    <DIR>          inference
# 28/11/2022  21:41            35,823 LICENSE.md
# 28/11/2022  22:34    <DIR>          models
# ...

# %%
#for the flower Image 1 model 1
# !python detect.py --weights yolov7_custom1.pt --conf 0.5 --img-size 640 --source totest/flower3.jpg --name testingflower3 --view-img

# %%
#for the flower Images and videos with model 2
# !python detect.py --weights yolov7_custom1.pt --conf 0.5 --img-size 640 --source totest/ --name w1flowers --view-img
# Out:
# Namespace(weights=['yolov7_custom1.pt'], source='totest/', img_size=640, conf_thres=0.5, iou_thres=0.45, device='', view_img=True, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='w1flowers', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 3 flowers, Done. (27.0ms) Inference, (4.0ms) NMS
#  The image with the result is saved in: runs\detect\w1flowers\flower1.jpg
# 2 flowers, Done. (27.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\w1flowers\flower2.jpg
# 6 flowers, Done. (27.0ms) Inference, (2.6ms) NMS
#  The image with the result is saved in: runs\detect\w1flowers\flower3.jpg
# 7 flowers, Done. (28.0ms) Inference, (1.0ms) NMS
# ...

# %%
#for the flower Images and videos with model 2
# !python detect.py --weights yolov7_custom2.pt --conf 0.5 --img-size 640 --source totest/ --name w2flowers --view-img
# Out:
# Namespace(weights=['yolov7_custom2.pt'], source='totest/', img_size=640, conf_thres=0.5, iou_thres=0.45, device='', view_img=True, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='w2flowers', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 1 flower, Done. (19.0ms) Inference, (4.0ms) NMS
#  The image with the result is saved in: runs\detect\w2flowers\flower1.jpg
# Done. (19.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\w2flowers\flower2.jpg
# 4 flowers, Done. (23.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\w2flowers\flower3.jpg
# 1 flower, Done. (84.0ms) Inference, (2.0ms) NMS
# ...

# %%
#!python detect.py --weights yolov7_custom.pt --conf 0.5 --img-size 640 --source flower1.jpg --view-img --no-trace
#!python train.py --batch-size 8 --epochs 50 --img 640 640 --data /content/gdrive/MyDrive/Colab_assets/yolov7/data/custom_data.yaml --hyp /content/gdrive/MyDrive/Colab_assets/yolov7/data/hyp.scratch.custom.yaml --cfg /content/gdrive/MyDrive/Colab_assets/yolov7/cfg/training/yolov7_custom.yaml --name yolov7-custom --weights yolov7.pt --device 0
